# %%
# Set do not allow duplicates, but list allows duplicates
# Sets have  no order/inndexing/slicing
# Sets dont allow mutable data types 
# Sets itself is a mutable data type, but it can only contain immutable data types

# %%
s = {}
type(s) # Output: <class 'dict'>, because {} creates a dictionary, not a set
# Out:
# dict

# %%
s1 = set()
print(s1)
# Out:
# set()

# %%
# Hashing  
s2 = {1, 2, 3, 4, 5}
print(s2)

a = hash("hello")
print(a) # Output: 69609650
# Out:
# {1, 2, 3, 4, 5}
# 8195112538943078542

# %%
d = {1, 2, 3, 4, 5}
d1 = {4, 5, 6, 7, 8}
d.union(d1) # Output: {1, 2, 3, 4, 5}
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}
