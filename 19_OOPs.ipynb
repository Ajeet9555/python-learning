# %%
# In python, everything is an object.
# Generality to specificity  - this is the principle of OOP (Object-Oriented Programming).

# %%
# OOPs
# Class is a blueprint for creating objects.
# Class always made in PascalCase(Like - TheClassName), 
# theClassName -> Camel case, the_class_name -> Snake case(fuction name, variable name, file name, etc.)

# %%
# Object is an instance of a class. It is a collection of data (variables) and methods (functions) that act on the data.

# %%
#Constructor : A special method in a class that is automatically called when an object of the class is created. It is used to initialize the attributes of the object. like - __init__

# %%
# Function vs Method
# Function is a block of code that is used to perform a specific task. It can be called without creating an object of the class. It is defined using the def keyword.
# Method is a function that is associated with an object. It can be called only by creating an object of the class. It is defined using the def keyword.

# %%
class Atm:
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()

    def menu(self):
        while True:
            user_input = input("""
            Hello, How would you like to proceed?
            1. Enter 1 to create PIN
            2. Enter 2 to deposit
            3. Enter 3 to withdraw
            4. Enter 4 to check balance
            5. Enter 5 to exit
            Enter your choice: """)
            if user_input == "1":
                self.create_pin()
            elif user_input == "2":
                self.deposit()
            elif user_input == "3":
                self.withdraw()
            elif user_input == "4":
                self.check_balance()
            elif user_input == "5":
                print("\nThank you for using our service.")
                break
            else:
                print("\nInvalid input. Please enter a number from 1 to 5.")

    def create_pin(self):
        self.pin = input("Enter your new PIN: ")
        if self.pin.isdigit() and len(self.pin) == 4:
            print("PIN created successfully.")
        else:
            print("PIN must be exactly 4 digits.")
            self.pin = ""

    def deposit(self):
        if self.pin == "":
            print("Please create a PIN first.")
            return
        temp_pin = input("Enter your PIN: ")
        if temp_pin == self.pin:
            try:
                amount = int(input("Enter the amount to deposit: "))
                if amount > 0:
                    self.balance += amount
                    print(
                        f"Amount deposited successfully. "
                        f"Your new balance is ₹{self.balance}"
                    )
                else:
                    print("Please enter an amount greater than 0.")
            except ValueError:
                print("Invalid amount. Please enter a number.")
        else:
            print("Invalid PIN. Please try again.")

    def withdraw(self):
        if self.pin == "":
            print("Please create a PIN first.")
            return
        temp_pin = input("Enter your PIN: ")
        if temp_pin == self.pin:
            try:
                amount = int(input("Enter the amount to withdraw: "))
                if amount <= 0:
                    print("Please enter an amount greater than 0.")
                elif amount <= self.balance:
                    self.balance -= amount
                    print(
                        f"Amount withdrawn successfully. "
                        f"Your new balance is ₹{self.balance}"
                    )
                else:
                    print("Insufficient balance.")
            except ValueError:
                print("Invalid amount. Please enter a number.")
        else:
            print("Invalid PIN. Please try again.")

    def check_balance(self):
        if self.pin == "":
            print("Please create a PIN first.")
            return
        temp_pin = input("Enter your PIN: ")
        if temp_pin == self.pin:
            print(f"Your current balance is ₹{self.balance}")
        else:
            print("Invalid PIN. Please try again.")

sbi = Atm()

# %%
x = 6/5
x
# Out:
# 1.2

# %%
class Fraction:
    def __init__(self,n,d):
        self.num = n
        self.den = d

    def __str__(self):
        return "{}/{}".format(self.num,self.den)

    def __add__(self,other):
        temp_num = self.num * other.den + self.den * other.num
        temp_den = self.den * other.den

        return "{}/{}".format(temp_num,temp_den)
    def __sub__(self,other):
        temp_num = self.num * other.den - self.den * other.num
        temp_den = self.den * other.den

        return "{}/{}".format(temp_num,temp_den)
    def __mul__(self,other):
        temp_num = self.num * other.num
        temp_den = self.den * other.den

        return "{}/{}".format(temp_num,temp_den)
    def __truediv__(self,other):
        temp_num = self.num * other.den
        temp_den = self.den * other.num

        return "{}/{}".format(temp_num,temp_den)

x = Fraction(1,2)
y = Fraction(1,4)

print(x)
print(y)
print(x + y)
print(x - y)
print(x * y)
print(x / y)
# Out:
# 1/2
# 1/4
# 6/8
# 2/8
# 1/8
# 4/2

# %%
# Encapsulation : The process of wrapping data and methods that operate on that data within a single unit (class). It restricts direct access to some of the object's components, which can prevent the accidental modification of data. In Python, encapsulation is achieved using private and protected access modifiers.

# %%
# Nothing is private in python, but we can use _ or __ to make it private. -> Because python is a adult language and we are responsible for our own actions.

# %%
class BankAccount:

    def __init__(self):
        self.__balance = 0   # Private variable

    def deposit(self, amount):
        self.__balance += amount

    def check_balance(self):
        print("Balance:", self.__balance)

account = BankAccount()

account.deposit(5000)
account.check_balance()
# Out:
# Balance: 5000

# %%
# Polymorphism : The ability of a function or method to work in different ways depending on the object it is acting upon. In Python, polymorphism is achieved through method overriding and operator overloading.

# %%
class Animal:
    def make_sound(self):
        pass

class Dog(Animal):
    def make_sound(self):
        return "Woof!"

class Cat(Animal):
    def make_sound(self):
        return "Meow!"

class Bird(Animal):
    def make_sound(self):
        return "Tweet!"

# Create instances of each class
dog = Dog()
cat = Cat()
bird = Bird()

# Call the make_sound method on each instance
print(dog.make_sound())
print(cat.make_sound())
print(bird.make_sound())
# Out:
# Woof!
# Meow!
# Tweet!

# %%
# Reference variable : A variable that holds the memory address of an object rather than the actual value of the object. In Python, all variables are reference variables, meaning they store references to objects in memory rather than the objects themselves.

# %%
class Customer:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender

    def greet(customer):
        if customer.gender == "Male":
            print(f"Hello Mr. {customer.name}")
        else:
            print(f"Hello Ms. {customer.name}")

        cust2 = Customer("Ajeet","Male")

        return cust2

cust = Customer("Akriti","Female")

new_cust = cust.greet()
print(new_cust.name)
# Out:
# Hello Ms. Akriti
# Ajeet

# %%
# Inheritance : The process by which one class (the child or subclass) can inherit the attributes and methods of another class (the parent or superclass). In Python, inheritance is achieved by defining a new class that derives from an existing class.

# %%
class Parent:
    def show(self):
        print("Parent class")


class Child(Parent):
    pass


c = Child()
c.show()
# Out:
# Parent class

# %%
# Abstraction : The process of hiding the implementation details and showing only the functionality to the user. In Python, abstraction is achieved using abstract classes and interfaces.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):

    @abstractmethod
    def sound(self):
        pass


class Dog(Animal):

    def sound(self):
        print("Bark")


d = Dog()
d.sound()
# Out:
# Bark

# %%
# OOP Concept -> Simple meaning
# Encapsulation -> Hide/protect data
# Inheritance -> Reuse code from another class
# Polymorphism -> One name, different behavior
# Abstraction -> Hide unnecessary details
