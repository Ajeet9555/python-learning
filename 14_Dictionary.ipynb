# %%
# Dictionary

# %%
{"Name": "Ajeet", "Age": 25, "City": "New Delhi"}
# Out:
# {'Name': 'Ajeet', 'Age': 25, 'City': 'New Delhi'}

# %%
# Rule
# Dictionary has no indexing
# Keys is mutable,but values can be mutable or immutable
# Keys should be unique

# %%
d = {"2, 3, 4, 5":"Ajeet"}
print(d)
# Out:
# {'2, 3, 4, 5': 'Ajeet'}
