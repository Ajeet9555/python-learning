# %%
print("India", "Nepal")
# Out:
# India Nepal

# %%
print("India", "Nepal", sep= " - ")
# Out:
# India - Nepal

# %%
print("India", "Nepal", sep= " / ")
# Out:
# India / Nepal

# %%
print("India", end= ' ')
print("Nepal")
# Out:
# India Nepal
