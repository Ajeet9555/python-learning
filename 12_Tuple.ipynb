# %%
# Tuple in Python
# Create
# Access
# Edit
# Add
# Delete
# Operations
# Fuctions

# %%
a = ("hello")
type(a)
# Out:
# str

# %%
b = ("hello",)
type(b)
# Out:
# tuple

# %%
a = (1, 2, 3, 4, 5) # Creating a tuple
print(a)
type(a) # Output: <class 'tuple'>
# Out:
# (1, 2, 3, 4, 5)
# tuple
