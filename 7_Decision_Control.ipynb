# %%
# correct email = "campusx@gmail.com"
# password = "campusx"
email = input("Enter your email: ")
if '@' in email:
    password = input("Enter your password: ") 
    if email == "campusx@gmail.com" and password == "campusx":
        print("Login successful")   
    elif email == "campusx@gmail.com" and password != "campusx":
        print("Password is incorrect")
        password = input("Enter your password again: ")
        if password == "campusx":
            print("Login successful")
        else:
            print("Login failed")
    else:
        print("Login failed")
else:
    print("Invalid email format")
# Out:
# Invalid email format

# %%
# Find the 2nd largest number in the list without sort()
numbers = [3, 1, 4, 8, 1, 5, 9]
largest = second_largest = float('-inf')
for num in numbers:
    if num > largest:
        second_largest = largest
        largest = num
    elif largest > num > second_largest:
        second_largest = num

print("The 2nd largest number is:", second_largest)
# Out:
# The 2nd largest number is: 8

# %%
# Find the 2nd largest number in the list by sorting
