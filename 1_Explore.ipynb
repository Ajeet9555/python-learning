# %% [markdown]
# # Main Heading
# ## Subheading
# ### small heading
#
# this is a regular text
#
# ---
#
# - Task List 1
# - Task List 2

# %% [markdown]
# - Esc → Command Mode (shortcuts work)
# - Enter → Edit Mode (typing)
#
# - esc + A → current cell ke upar new cell add karega
#      - B → current cell ke niche new cell addkarega
#      - Y → cell ko Code cell bana dega
#      - M → cell ko Markdown cell bana dega

# %%
print("Ajeet Singh")
# Out:
# Ajeet Singh

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Sine Wave")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
